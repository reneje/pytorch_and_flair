# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.nn import functional as F

# %%
class RNN(nn.Module):
    
    def __init__(self, batch_size, output_size, hidden_size, vocab_size,
                embedding_length, weigths):
        super(RNN, self).__init__()
        """
        Arguments
        ---------
        batch_size : Size of the batch which is same as the batch_size of the data returned by the TorchText BucketIterator
        output_size : 2 = (pos, neg)
        hidden_sie : Size of the hidden_state of the LSTM
        vocab_size : Size of the vocabulary containing unique words
        embedding_length : Embeddding dimension of GloVe word embeddings
        weights : Pre-trained GloVe word_embeddings which we will use to create our word_embedding look-up table 

        """
        
        self.batch_size = batch_size
        self.output_size = output_size
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.embedding_length = embedding_length
        
        self.word_embedding = nn.Embedding(vocab_size, embedding_length)
        self.word_embedding.weigths = nn.Parameter(weights, requires_grad=False)
        self.rnn = nn.RNN(embedding_length, hidden_size, 
                          num_layers=2,bidirectional=True)
        self.label = nn.Linear(4*hidden_size,output_size)
        
    def forward(self, input_sentences, batch_size=None):
        """ 
        Parameters
        ----------
        input_sentence: input_sentence of shape = (batch_size, num_sequences)
        batch_size : default = None. Used only for prediction on a single sentence after training (batch_size = 1)

        Returns
        -------
        Output of the linear layer containing logits for pos & neg class which receives its input as the final_hidden_state of RNN.
        logits.size() = (batch_size, output_size)

        """
        
        input = self.word_embedding(input_sentences)
        input = input.permute(1,0,2)
        
        if batch_size is None:
            h_0 = Variable(torch.zeros(4, self.batch_size, self.hidden_size).cuda())
        else:
            h_0 = Variable(torch.zeros(4, batch_size, self.hidden_size).cuda())
        
        output, h_n = self.rnn(input,h_0)
        
        # h_n.size() = (4, batch_size, hidden_size)
        h_n = h_n.permute(1,0,2)
        h_n = h_n.contiguous().view(h_n.size()[0], h_n.size()[1]*h_n.size()[2])
        
        # h_n.size() = (batch_size, 4*hidden_size)
        logits = self.label(h_n)
        
        return logits

# %%
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.datasets import fetch_20newsgroups

x = torch.IntTensor([1,3,6])
y = torch.IntTensor([1,1,1])
result = x + y
print(result)
# Out:
# tensor([2, 4, 7], dtype=torch.int32)

# %%
categories = ["comp.graphics","sci.space","rec.sport.baseball"]
newsgroups_train = fetch_20newsgroups(subset='train', categories=categories)
newsgroups_test = fetch_20newsgroups(subset='test', categories=categories)

print('total texts in train:',len(newsgroups_train.data))
print('total texts in test:',len(newsgroups_test.data))
# Out:
# Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)
# total texts in train: 1774
# total texts in test: 1180

# %%
vocab = Counter()

for text in newsgroups_train.data:
    for word in text.split(' '):
        vocab[word.lower()]+=1

for text in newsgroups_test.data:
    for word in text.split(' '):
        vocab[word.lower()]+=1

total_words = len(vocab)

def get_word_2_index(vocab):
    word2index = {}
    for i,word in enumerate(vocab):
        word2index[word.lower()] = i

    return word2index

word2index = get_word_2_index(vocab)

word2index
# Out:
# {'from:': 0,
#  'jk87377@lehtori.cc.tut.fi': 1,
#  '(kouhia': 2,
#  'juhana)\nsubject:': 3,
#  're:': 4,
#  'more': 5,
#  'gray': 6,
#  'levels': 7,
#  'out': 8,
#  'of': 9,
#  'the': 10,
#  'screen\norganization:': 11,
#  'tampere': 12,
#  'university': 13,
#  'technology\nlines:': 14,
#  '21\ndistribution:': 15,
#  'inet\nnntp-posting-host:': 16,
#  'cc.tut.fi\n\nin': 17,
#  'article': 18,
#  '<1993apr6.011605.909@cis.uab.edu>': 19,
#  'sloan@cis.uab.edu\n(kenneth': 20,
#  'sloan)': 21,
#  'writes:\n>\n>why': 22,
#  "didn't": 23,
#  'you': 24,
#  'create': 25,
#  '8': 26,
#  'grey-level': 27,
#  'images,': 28,
#  'and': 29,
#  'display': 30,
#  'them': 31,
#  'for\n>1,2,4,8,16,32,64,128...': 32,
#  'time': 33,
#  'slices?\n\nby': 34,
#  "'8": 35,
#  'grey': 36,
#  'level': 37,
#  "images'": 38,
#  'mean': 39,
#  'items': 40,
#  '1bit': 41,
#  'images?\nit': 42,
#  'does': 43,
#  'work(!),': 44,
#  'but': 45,
#  'it': 46,
#  "doesn't": 47,
#  'work': 48,
#  'if': 49,
#  'have': 50,
#  'than': 51,
#  '1bit\nin': 52,
#  'your': 53,
#  'screen': 54,
#  'intensity': 55,
#  'is': 56,
#  'non-linear.\n\nwith': 57,
#  '2': 58,
#  'bit': 59,
#  'per': 60,
#  'pixel;': 61,
#  'there': 62,
#  'could': 63,
#  'be': 64,
#  '1*c_1': 65,
#  '+': 66,
#  '4*c_2': 67,
#  'timing,\nthis': 68,
#  'gives': 69,
#  '16': 70,
#  'levels,': 71,
#  'they': 72,
#  'are': 73,
#  'linear': 74,
#  'is\nlinear.\nwith': 75,
#  '2*c_2': 76,
#  'works,': 77,
#  'we': 78,
#  'to': 79,
#  'find': 80,
#  'best\ncompinations': 81,
#  '--': 82,
#  "there's": 83,
#  '10': 84,
#  'choises;': 85,
#  'best': 86,
#  'must': 87,
#  'be\nchosen.': 88,
#  'different': 89,
#  'compinations': 90,
#  'for': 91,
#  'same': 92,
#  'level,': 93,
#  'varies': 94,
#  'a': 95,
#  'bit,': 96,
#  'but\nthe': 97,
#  'keeps': 98,
#  'their': 99,
#  'order.\n\nreaders': 100,
#  'should': 101,
#  'verify': 102,
#  'what': 103,
#  'i': 104,
#  'wrote...': 105,
#  ':-)\n\njuhana': 106,
#  'kouhia\n': 107,
#  'jbulf@balsa.berkeley.edu': 108,
#  '(jeff': 109,
#  'bulf)\nsubject:': 110,
#  'detecting': 111,
#  'double': 112,
#  'points': 113,
#  'in': 114,
#  'bezier': 115,
#  'curves\nreply-to:': 116,
#  'bulf)\norganization:': 117,
#  'kubota': 118,
#  'pacific': 119,
#  'computers': 120,
#  'inc.\nlines:': 121,
#  '20\n\nin': 122,
#  '<ia522b1w165w@oeinck.waterland.wlink.nl>,': 123,
#  'ferdinan@oeinck.waterland.wlink.nl': 124,
#  '(ferdinand': 125,
#  'oeinck)': 126,
#  'writes:\n|>': 127,
#  "i'm": 128,
#  'looking': 129,
#  'any': 130,
#  'information': 131,
#  'on': 132,
#  'and/or': 133,
#  'calculating': 134,
#  'double\n|>': 135,
#  'point': 136,
#  'cusp': 137,
#  'curve.\n|>': 138,
#  '\n|>': 139,
#  'an': 140,
#  'algorithm,': 141,
#  'literature': 142,
#  'reference': 143,
#  'or': 144,
#  'mail': 145,
#  'about': 146,
#  'this': 147,
#  'very': 148,
#  'appreciated,\n\nthere': 149,
#  'was': 150,
#  'useful': 151,
#  'one': 152,
#  '1989': 153,
#  'issues': 154,
#  'of\ntransactions': 155,
#  'graphics.': 156,
#  'believe': 157,
#  'maureen': 158,
#  'stone': 159,
#  'of\nthe': 160,
#  'authors.': 161,
#  'sorry': 162,
#  'not': 163,
#  'specific.': 164,
#  "don't": 165,
#  'the\nreference': 166,
#  'here': 167,
#  'with': 168,
#  'me.\n\nthe': 169,
#  'actually': 170,
#  'general': 171,
#  'this,': 172,
#  'giving': 173,
#  'way': 174,
#  'decide\nwhether': 175,
#  'given': 176,
#  '(cubic)': 177,
#  'curve': 178,
#  'contains': 179,
#  'cusps,': 180,
#  'intersection': 181,
#  'points\nor': 182,
#  'whatever': 183,
#  'wierdness.': 184,
#  'treatment': 185,
#  'also': 186,
#  'available': 187,
#  'siggraph': 188,
#  '89\ncourse': 189,
#  'notes': 190,
#  'course': 191,
#  'called': 192,
#  '"math': 193,
#  'siggraph"': 194,
#  'something': 195,
#  'like\nthat.\n\n--': 196,
#  '\n\tdr': 197,
#  'memory\n\tjbulf@kpc.com\n': 198,
#  'jrogoff@scott.skidmore.edu': 199,
#  '(jay': 200,
#  'rogoff)\nsubject:': 201,
#  "'61": 202,
#  'orioles': 203,
#  'trivia\norganization:': 204,
#  'skidmore': 205,
#  'college,': 206,
#  'saratoga': 207,
#  'springs': 208,
#  'ny\nlines:': 209,
#  '6\n\n\nbunker': 210,
#  '&': 211,
#  'mcnally': 212,
#  'were': 213,
#  'later.\n\npappas,': 214,
#  'estrada,': 215,
#  'steve': 216,
#  'barber,': 217,
#  '.': 218,
#  '?\n\njay\n': 219,
#  'kwp@wag.caltech.edu': 220,
#  '(kevin': 221,
#  'w.': 222,
#  'plaxco)\nsubject:': 223,
#  'boom!': 224,
#  '': 225,
#  'whoosh......\norganization:': 226,
#  'california': 227,
#  'institute': 228,
#  'technology,': 229,
#  'pasadena,': 230,
#  'ca\nlines:': 231,
#  '22\nnntp-posting-host:': 232,
#  'sgi1.wag.caltech.edu\n\nin': 233,
#  '<37147@scicom.alphacdc.com>': 234,
#  'wats@scicom.alphacdc.com': 235,
#  '(bruce': 236,
#  'watson)': 237,
#  'writes:\n>+\n>pageos': 238,
#  'two': 239,
#  'echo': 240,
#  'balloons': 241,
#  'inflated': 242,
#  'substance\n>which': 243,
#  'expanded': 244,
#  'vacuum.': 245,
#  '\n\ncalled': 246,
#  '"gas".\n\n>once': 247,
#  'substance': 248,
#  'no': 249,
#  'longer\n>needed': 250,
#  'since': 251,
#  'nothing': 252,
#  'cause': 253,
#  'balloon': 254,
#  'collapse.\n>this': 255,
#  'inflatable': 256,
#  'structure': 257,
#  'suffer': 258,
#  'multiple': 259,
#  'holes': 260,
#  '\n>disastrous': 261,
#  'deflation.\n\nthe': 262,
#  'sufficiently': 263,
#  'low': 264,
#  'orbit': 265,
#  'that': 266,
#  'experienced\nsome': 267,
#  'air': 268,
#  'resistance.': 269,
#  'when': 270,
#  'finally': 271,
#  'punctured,': 272,
#  '\npreasure': 273,
#  '(and': 274,
#  'internal': 275,
#  'preasure': 276,
#  'needed': 277,
#  'maintain\na': 278,
#  'spherical': 279,
#  'shape': 280,
#  'against': 281,
#  'resistance)': 282,
#  'caused': 283,
#  'to\ncatastrophically': 284,
#  'deflated.': 285,
#  'large': 286,
#  'silvered': 287,
#  'shards\nthat': 288,
#  'remained': 289,
#  'easily': 290,
#  'visible': 291,
#  'some': 292,
#  'before\nreentry,': 293,
#  'though': 294,
#  'longer': 295,
#  'as': 296,
#  'passive': 297,
#  'transponder.\n\nthe': 298,
#  'billboard': 299,
#  'pop': 300,
#  'like': 301,
#  'dime': 302,
#  'store': 303,
#  'balloon.\n\n': 304,
#  'sbp002@acad.drake.edu\nsubject:': 305,
#  'braves': 306,
#  'pitching': 307,
#  'updatedir\nlines:': 308,
#  '12\nnntp-posting-host:': 309,
#  'acad.drake.edu\norganization:': 310,
#  'drake': 311,
#  'university,': 312,
#  'des': 313,
#  'moines,': 314,
#  'iowa,': 315,
#  'usa\n\n': 316,
#  '\n>': 317,
#  'clear': 318,
#  'me': 319,
#  'at': 320,
#  'all.': 321,
#  "i'd": 322,
#  'certainly': 323,
#  'rather': 324,
#  'team': 325,
#  'who': 326,
#  'winning\n>': 327,
#  '4-1': 328,
#  'games': 329,
#  '2-1': 330,
#  'games.': 331,
#  'game,': 332,
#  'luck': 333,
#  'going': 334,
#  'play': 335,
#  'much\n>': 336,
#  'bigger': 337,
#  'role': 338,
#  'game.': 339,
#  '\n\nbut': 340,
#  'still': 341,
#  'need': 342,
#  'staff': 343,
#  'hold': 344,
#  'opposing': 345,
#  'to\none': 346,
#  'run.\n\nsam\n>': 347,
#  'sherri': 348,
#  'nichols\n>': 349,
#  'snichols@adobe.com\n': 350,
#  'cmk@athena.mit.edu': 351,
#  '(charles': 352,
#  'm': 353,
#  'kozierok)\nsubject:': 354,
#  'detroit': 355,
#  'tigers\norganization:': 356,
#  'massachusetts': 357,
#  '20\nnntp-posting-host:': 358,
#  'marinara.mit.edu\nkeywords:': 359,
#  'top': 360,
#  'offensive': 361,
#  'league\n\nin': 362,
#  '<1qt1f3$o7o@msuinfo.cl.msu.edu>': 363,
#  'vergolin@euler.lbs.msu.edu': 364,
#  '(david': 365,
#  'vergolini)': 366,
#  'writes:\n}': 367,
#  'roar': 368,
#  'michigan': 369,
#  'trumbull': 370,
#  'loader': 371,
#  'ever': 372,
#  'year.': 373,
#  'with\n}': 374,
#  'mike': 375,
#  'illitch': 376,
#  'head': 377,
#  'ernie': 378,
#  'harwell': 379,
#  'back': 380,
#  'booth,': 381,
#  'tiger': 382,
#  'bats\n}': 383,
#  'will': 384,
#  'bang': 385,
#  'summer.': 386,
#  'already': 387,
#  'scored': 388,
#  '20': 389,
#  'runs': 390,
#  'fielder,': 391,
#  'tettleton,': 392,
#  'deer': 393,
#  'think': 394,
#  'can': 395,
#  'win': 396,
#  'division.': 397,
#  'pitching!\n}': 398,
#  'bull!': 399,
#  'gully,': 400,
#  'moore,': 401,
#  'wells,': 402,
#  'krueger': 403,
#  'make': 404,
#  'up': 405,
#  'decent': 406,
#  'keep\n}': 407,
#  'into': 408,
#  'many': 409,
#  'then': 410,
#  'henneman': 411,
#  'close': 412,
#  'out.': 413,
#  'watch': 414,
#  'out\n}': 415,
#  'boston,': 416,
#  'toronto,': 417,
#  'baltimore': 418,
#  '-': 419,
#  'motor': 420,
#  'city': 421,
#  'kittys': 422,
#  'back.\n\nnice': 423,
#  'woofing': 424,
#  '(or': 425,
#  'say': 426,
#  'meowing?).\nand': 427,
#  'yes,': 428,
#  'tiggers': 429,
#  'fun,': 430,
#  'exciting': 431,
#  'would': 432,
#  'pay': 433,
#  'see.\nbut': 434,
#  'last': 435,
#  'year,': 436,
#  'went': 437,
#  '75-87.': 438,
#  'offense': 439,
#  'essentially\nthe': 440,
#  'same,': 441,
#  'is,': 442,
#  'best,': 443,
#  'essentially': 444,
#  'same.': 445,
#  'so': 446,
#  'why\ndo': 447,
#  'suddenly': 448,
#  'improve': 449,
#  '92': 450,
#  'which': 451,
#  'will\nbe': 452,
#  'required': 453,
#  'a.l.': 454,
#  'east?': 455,
#  'has': 456,
#  'changed': 457,
#  'see?\n\nremember,': 458,
#  '20-4': 459,
#  'worth': 460,
#  'much': 461,
#  'standings': 462,
#  '3-2': 463,
#  'win...\n\n-*-\ncharles\n': 464,
#  'amann@iam.unibe.ch': 465,
#  '(stephan': 466,
#  'amann)\nsubject:': 467,
#  'radiosity\nreply-to:': 468,
#  'amann@iam.unibe.ch\norganization:': 469,
#  'berne,': 470,
#  'computer': 471,
#  'science': 472,
#  'applied': 473,
#  'mathematics,': 474,
#  'special': 475,
#  'interest': 476,
#  'group': 477,
#  'graphics\nlines:': 478,
#  '54\n\nin': 479,
#  '16598@rz.uni-jena.de,': 480,
#  'hahm@fossi.hab-weimar.de': 481,
#  '(peter': 482,
#  'hahm)': 483,
#  'writes:\n>\n>\n>radiosity': 484,
#  'sources': 485,
#  'wanted': 486,
#  '!!!\n>============================\n>\n>when': 487,
#  'read': 488,
#  'comp.graphics': 489,
#  'group,': 490,
#  'never': 491,
#  'found': 492,
#  '\n>radiosity.': 493,
#  'anybody': 494,
#  'interested': 495,
#  'there?': 496,
#  'glad': 497,
#  '\n>to': 498,
#  'hear': 499,
#  'from': 500,
#  'somebody.\n>i': 501,
#  'am': 502,
#  'source-code': 503,
#  'radiosity-method.': 504,
#  'already\n>read': 505,
#  'common': 506,
#  'literature,': 507,
#  'e.': 508,
#  'g.foley': 509,
#  '...': 510,
#  'little': 511,
#  'examples': 512,
#  '\n>help': 513,
#  'understand': 514,
#  'how': 515,
#  'radiosity': 516,
#  'works.': 517,
#  'languages': 518,
#  '(': 519,
#  'c,': 520,
#  'c++,': 521,
#  '\n>pascal)': 522,
#  'prefered.\n>i': 523,
#  'hope': 524,
#  'help': 525,
#  'me!\n>\n>yours\n>peter': 526,
#  '\n>\n\n\npeter,': 527,
#  'package': 528,
#  'ahead.': 529,
#  'only': 530,
#  'problem': 531,
#  'is:': 532,
#  '\nare': 533,
#  'few': 534,
#  'miles': 535,
#  'sail': 536,
#  ";-^\n\nlet's": 537,
#  'serious...': 538,
#  'working': 539,
#  'package,': 540,
#  'written': 541,
#  'c++.\ni': 542,
#  'public': 543,
#  'domain.': 544,
#  "i'll": 545,
#  'announce': 546,
#  'c.g.': 547,
#  'minute\ni': 548,
#  'finished': 549,
#  'it.': 550,
#  '\n\nthat': 551,
#  'good': 552,
#  'news.': 553,
#  'bad': 554,
#  'news:': 555,
#  "it'll": 556,
#  'take': 557,
#  'another': 558,
#  'months': 559,
#  '(at': 560,
#  'least)': 561,
#  '\nto': 562,
#  'finish': 563,
#  '\n\nin': 564,
#  'meantime': 565,
#  'may': 566,
#  'look': 567,
#  'file\n': 568,
#  'radiosity_code.tar.z\nlocated': 569,
#  'at\n': 570,
#  'compute1.cc.ncsu.edu\n\n(there': 571,
#  'other': 572,
#  'locations;': 573,
#  'archie': 574,
#  'get': 575,
#  'nearest)\n\nhope': 576,
#  "that'll": 577,
#  'help.\n\nyours\n\nstephan\n\n\n\n----------------------------------------------------------------------------\n\n': 578,
#  'stephan': 579,
#  'amann': 580,
#  'sig': 581,
#  'graphics,': 582,
#  'switzerland\n': 583,
#  'amann@iam.unibe.ch\n\t': 584,
#  'tel': 585,
#  '+41': 586,
#  '31': 587,
#  '65': 588,
#  '46': 589,
#  '79\t': 590,
#  'fax': 591,
#  '39': 592,
#  '65\n\n': 593,
#  'projects:': 594,
#  'radiosity,': 595,
#  'raytracing,': 596,
#  'graphics\n\n----------------------------------------------------------------------------\n': 597,
#  'ricardo@rchland.vnet.ibm.com': 598,
#  '(ricardo': 599,
#  'hernandez': 600,
#  'muchado)\nsubject:': 601,
#  'newsgroup': 602,
#  'split\ndisclaimer:': 603,
#  'posting': 604,
#  'represents': 605,
#  "poster's": 606,
#  'views,': 607,
#  'necessarily': 608,
#  'those': 609,
#  'ibm\nnntp-posting-host:': 610,
#  'rs43873.rchland.ibm.com\norganization:': 611,
#  'ibm': 612,
#  'rochester\nlines:': 613,
#  '21\n\nin': 614,
#  '<1quvdoinn3e7@srvr1.engin.umich.edu>,': 615,
#  'tdawson@engin.umich.edu': 616,
#  '(chris': 617,
#  'herringshaw)': 618,
#  'concerning': 619,
#  'proposed': 620,
#  'split,': 621,
#  'personally': 622,
#  'favor': 623,
#  'of\n|>': 624,
#  'doing': 625,
#  'this.': 626,
#  'learn': 627,
#  'awful': 628,
#  'lot': 629,
#  'all': 630,
#  'aspects': 631,
#  'graphics': 632,
#  'by': 633,
#  'reading\n|>': 634,
#  'code': 635,
#  'hardware': 636,
#  'algorithms.': 637,
#  'just': 638,
#  'making': 639,
#  '5\n|>': 640,
#  'groups': 641,
#  'wate,': 642,
#  'result': 643,
#  'posts\n|>': 644,
#  'week': 645,
#  'group.': 646,
#  'kind': 647,
#  'convenience': 648,
#  'having': 649,
#  'big': 650,
#  'forum\n|>': 651,
#  'discussing': 652,
#  'anyone': 653,
#  'else': 654,
#  'feel': 655,
#  'way?\n|>': 656,
#  'curious.\n|>': 657,
#  'daemon\n|>': 658,
#  '\n\n': 659,
#  'agree': 660,
#  'you.\n\n--------------------------------------\nraist': 661,
#  'new': 662,
#  'a1200': 663,
#  'owner': 664,
#  '320<->1280': 665,
#  'x,': 666,
#  '200<->600': 667,
#  'y\nin': 668,
#  '256,000+': 669,
#  'colors': 670,
#  '24-bit': 671,
#  'palette.': 672,
#  '**i': 673,
#  'love': 674,
#  'it!**<-': 675,
#  'fat': 676,
#  ".sig\n*don't": 677,
#  'e-mail': 678,
#  'me*': 679,
#  '->': 680,
#  'valid': 681,
#  'address': 682,
#  'nor': 683,
#  'send': 684,
#  'e-mail\n\n': 685,
#  '\n': 686,
#  'ccgwt@trentu.ca': 687,
#  '(grant': 688,
#  'totten)\nsubject:': 689,
#  'ms-windows': 690,
#  'grabber?\nkeywords:': 691,
#  'windows': 692,
#  'grab': 693,
#  'document': 694,
#  '20\nreply-to:': 695,
#  'totten)\norganization:': 696,
#  'trent': 697,
#  'university\n\n\nhowdy': 698,
#  'all,\n\nwhere': 699,
#  'screen-grabber': 700,
#  'program': 701,
#  'ms-windows?': 702,
#  '\nwriting': 703,
#  'documentation': 704,
#  'helpful': 705,
#  'include\nsample': 706,
#  'screens': 707,
#  'document.\n\nplease': 708,
#  'usualy': 709,
#  'follow': 710,
#  'group.\n\nthanks': 711,
#  'lot,\n\ngrant\n\n--\ngrant': 712,
#  'totten,': 713,
#  'programmer/analyst,': 714,
#  'peterborough': 715,
#  'ontario\ngtotten@trentu.ca': 716,
#  'phone:': 717,
#  '(705)': 718,
#  '748-1653': 719,
#  'fax:': 720,
#  '748-1246\n========================================================================\n"the': 721,
#  'human': 722,
#  'brain': 723,
#  'enormous': 724,
#  'fish': 725,
#  'flat': 726,
#  'slimy': 727,
#  'and\nhas': 728,
#  'gills': 729,
#  'through': 730,
#  'see."\n\t\t--': 731,
#  'monty': 732,
#  'python\n': 733,
#  'subject:': 734,
#  'designated': 735,
#  'hitter': 736,
#  'rule\nfrom:': 737,
#  'holsend@mhd.moorhead.msus.edu\nreply-to:': 738,
#  'holsend@mhd.moorhead.msus.edu\norganization:': 739,
#  'moorhead': 740,
#  'state': 741,
#  'moorhead,': 742,
#  'mn\nnntp-posting-host:': 743,
#  '134.29.97.2\nlines:': 744,
#  '14\n\n\n\n\nin': 745,
#  '<ekdfc.14.0@ttacs1.ttu.edu>,': 746,
#  'ekdfc@ttacs1.ttu.edu': 747,
#  'coons)': 748,
#  'writes:\n>in': 749,
#  '<1993apr4.221228.17577@bsu-ucs>': 750,
#  '00ecgillespi@leo.bsuvc.bsu.edu': 751,
#  '\n>writes:\n>>i': 752,
#  'postition': 753,
#  'paper': 754,
#  'rule.': 755,
#  'information\n>>or': 756,
#  'even': 757,
#  'opinions': 758,
#  'greatly': 759,
#  'apprecitated.': 760,
#  '00ecgillespie': 761,
#  '"magic"\n>\n>should': 762,
#  'rescinded.': 763,
#  'rules': 764,
#  'baseball': 765,
#  'game': 766,
#  'between': 767,
#  'teams': 768,
#  '\n>nine': 769,
#  'players': 770,
#  'each.': 771,
#  "let's": 772,
#  'keep': 773,
#  'way.\n\nlast': 774,
#  'weeks': 775,
#  'sports': 776,
#  'illustrated': 777,
#  'couple': 778,
#  'articles': 779,
#  'designated\nhitter.': 780,
#  '1993': 781,
#  'issue.': 782,
#  'th': 783,
#  'illustrated\n': 784,
#  'prestonm@cs.man.ac.uk': 785,
#  '(martin': 786,
#  'preston)\nsubject:': 787,
#  'tiff:': 788,
#  'philosophical': 789,
#  'significance': 790,
#  '42\nlines:': 791,
#  '18\n\nin': 792,
#  '<c5scgu.1ll@mentor.cc.purdue.edu>': 793,
#  'ab@nova.cc.purdue.edu': 794,
#  '(allen': 795,
#  'b)': 796,
#  "writes:\n\n>i've": 797,
#  'got': 798,
#  '6.0': 799,
#  'spec': 800,
#  '(obviously': 801,
#  'quoted': 802,
#  'my': 803,
#  'posting).': 804,
#  '\n>my': 805,
#  'gripe': 806,
#  'tiff': 807,
#  "it's": 808,
#  'far': 809,
#  'too': 810,
#  'complicated': 811,
#  'nearly\n>infinitely': 812,
#  'easier': 813,
#  'write': 814,
#  'read,...\n\nwhy': 815,
#  'use': 816,
#  'pd': 817,
#  'c': 818,
#  'library': 819,
#  'reading/writing': 820,
#  'files?': 821,
#  'took': 822,
#  'a\ngood': 823,
#  'minutes': 824,
#  'start': 825,
#  'using': 826,
#  'own': 827,
#  'app.\n\nmartin\n\n--\n---------------------------------------------------------------------------\n|martin': 828,
#  'preston,': 829,
#  '(m.preston@manchester.ac.uk)': 830,
#  '|': 831,
#  '|\n|computer': 832,
#  'unit,': 833,
#  'manchester': 834,
#  'computing': 835,
#  'centre,': 836,
#  '|\n|university': 837,
#  'manchester,': 838,
#  'load': 839,
#  'balls.': 840,
#  '|\n|manchester,': 841,
#  'u.k.,': 842,
#  'm13': 843,
#  '9pl': 844,
#  'phone': 845,
#  ':': 846,
#  '061': 847,
#  '275': 848,
#  '6095': 849,
#  '|\n---------------------------------------------------------------------------\n': 850,
#  'tedward@cs.cornell.edu': 851,
#  '(edward': 852,
#  '[ted]': 853,
#  'fischer)\nsubject:': 854,
#  'old': 855,
#  'predictions': 856,
#  'laugh': 857,
#  'at...\norganization:': 858,
#  'cornell': 859,
#  'univ.': 860,
#  'cs': 861,
#  'dept,': 862,
#  'ithaca': 863,
#  'ny': 864,
#  '14853\nlines:': 865,
#  '12\n\nin': 866,
#  '<c5jcrf.krm@news.udel.edu>': 867,
#  'philly@ravel.udel.edu': 868,
#  '(robert': 869,
#  'hite)': 870,
#  'writes:\n>\n>dead': 871,
#  'wrong!': 872,
#  'checked,': 873,
#  'jim': 874,
#  'fregosi': 875,
#  'managing': 876,
#  'the\n>phillies,': 877,
#  'quite': 878,
#  'fine': 879,
#  'job': 880,
#  'thank': 881,
#  'you...best': 882,
#  'record': 883,
#  'in\n>baseball': 884,
#  '8-1\n\nlook,': 885,
#  'asshole,': 886,
#  'him': 887,
#  'confused': 888,
#  'somebody': 889,
#  'else.': 890,
#  'flame\nyou,': 891,
#  'appreciate': 892,
#  'extended': 893,
#  'courtesy.\n\nno,': 894,
#  'know': 895,
#  'everything': 896,
#  'world.': 897,
#  'surprise': 898,
#  'you?\n\n-valentine\n': 899,
#  'spira@panix.com': 900,
#  '(greg': 901,
#  'spira)\nsubject:': 902,
#  "america's": 903,
#  'is....but': 904,
#  'why?\norganization:': 905,
#  'panix': 906,
#  'access': 907,
#  'internet': 908,
#  'unix,': 909,
#  'nyc\nlines:': 910,
#  '<c5p3yr.gh2@news.cso.uiuc.edu>': 911,
#  'cka52397@uxa.cso.uiuc.edu': 912,
#  '(oriolefan@uiuc)': 913,
#  'writes:\n>\n>\tthe': 914,
#  'defenition': 915,
#  'underdog': 916,
#  'talent': 917,
#  'comes\n>out': 918,
#  'nowhere': 919,
#  'contend.': 920,
#  "'69": 921,
#  'mets': 922,
#  "'89": 923,
#  'prime': 924,
#  'examples,\n\nuh,': 925,
#  'call': 926,
#  'tom': 927,
#  'seaver,': 928,
#  'jerry': 929,
#  'koosman,\nand': 930,
#  'nolan': 931,
#  'ryan': 932,
#  '"no': 933,
#  'talent."': 934,
#  'they\ndid': 935,
#  'come': 936,
#  'nowhere,': 937,
#  'improvement': 938,
#  'was\nforseeable.': 939,
#  '\n\ngreg': 940,
#  'traven@pitt.edu': 941,
#  '(neal': 942,
#  'traven)\nsubject:': 943,
#  '1964': 944,
#  'phillies:': 945,
#  'deja': 946,
#  'vu?\nlines:': 947,
#  '25\nx-newsreader:': 948,
#  'tin': 949,
#  '[version': 950,
#  '1.1': 951,
#  'pl8]\n\nrobert': 952,
#  'hite': 953,
#  '(philly@bach.udel.edu)': 954,
#  'wrote:\n:': 955,
#  'most': 956,
#  'problems': 957,
#  'mainly': 958,
#  'arose': 959,
#  'manager': 960,
#  'gene': 961,
#  "mauch's\n:": 962,
#  'ineptitude': 963,
#  'staff.': 964,
#  'down': 965,
#  'stretch,': 966,
#  'he\n:': 967,
#  'abused': 968,
#  'bunning,': 969,
#  'chris': 970,
#  'short,': 971,
#  'robin': 972,
#  'roberts': 973,
#  '(i': 974,
#  'those\n:': 975,
#  'three)': 976,
#  'each': 977,
#  'days': 978,
#  'rest': 979,
#  'some\n:': 980,
#  'time.': 981,
#  'hit': 982,
#  'season,\n:': 983,
#  'obviously': 984,
#  'none': 985,
#  'these': 986,
#  'guys': 987,
#  'had': 988,
#  'ounce': 989,
#  'left': 990,
#  'arm.': 991,
#  'oh\n:': 992,
#  'well.\n\nroberts': 993,
#  'long': 994,
#  'gone': 995,
#  'he': 996,
#  'probably': 997,
#  'oriole': 998,
#  '1964.': 999,
#  ...}

# %%
def get_batch(df,i,batch_size):
    batches = []
    results = []
    texts = df.data[i*batch_size:i*batch_size+batch_size]
    categories = df.target[i*batch_size:i*batch_size+batch_size]
    for text in texts:
        layer = np.zeros(total_words,dtype=float)
        for word in text.split(' '):
            layer[word2index[word.lower()]] += 1

        batches.append(layer)

    for category in categories:
        index_y = -1
        if category == 0:
            index_y = 0
        elif category == 1:
            index_y = 1
        else:
            index_y = 2
        results.append(index_y)


    return np.array(batches),np.array(results)

# %%
# Parameters
learning_rate = 0.01
num_epochs = 10
batch_size = 150
display_step = 1

# Network Parameters
hidden_size = 100      # 1st layer and 2nd layer number of features
input_size = total_words # Words in vocab
num_classes = 3         # Categories: graphics, sci.space and baseball

# %%
# input [batch_size, n_labels]
# output [max index for each item in batch, ... ,batch_size-1]
loss = nn.CrossEntropyLoss()
input = Variable(torch.randn(2, 5), requires_grad=True)
print(">>> batch of size 2 and 5 possible classes")
print(input)
target = Variable(torch.LongTensor(2).random_(5))
print(">>> array of size 'batch_size' with the index of the maxium label for each item")
print(target)
output = loss(input, target)
output.backward()
# Out:
# >>> batch of size 2 and 5 possible classes
# tensor([[ 1.4892, -0.4042, -0.0267, -1.6635, -1.2048],
#         [-0.8111,  0.9500,  0.6461,  1.3036,  1.1003]], requires_grad=True)
# >>> array of size 'batch_size' with the index of the maxium label for each item
# tensor([0, 0])
